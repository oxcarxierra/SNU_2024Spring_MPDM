# %%
# !pip install cbs_mapf

# %%
from cbs_mapf.planner import Planner
import numpy as np

# %%
planner = Planner(grid_size=0.1,robot_radius=0.5,static_obstacles=[(10,5)])
planner.plan(starts=[[0,0],[20,0],[20,10],[0,10]], goals=[[20,10],[0,10],[0,0],[20,0]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-cd34088bd0e0> in <cell line: 1>()
# ----> 1 planner = Planner(grid_size=0.1,robot_radius=0.5,static_obstacles=[(10,5)])
#       2 planner.plan(starts=[[0,0],[20,0],[20,10],[0,10]], goals=[[20,10],[0,10],[0,0],[20,0]])
#
# /usr/local/lib/python3.10/dist-packages/cbs_mapf/planner.py in __init__(self, grid_size, robot_radius, static_obstacles)
#      29
#      30         self.robot_radius = robot_radius
# ---> 31         self.st_planner = STPlanner(grid_size, robot_radius, static_obstacles)
#      32
#      33     '''
#
# /usr/local/lib/python3.10/dist-packages/stastar/planner.py in __init__(self, grid_size, robot_radius, static_obstacles)
#      26
#      27         # Make the grid according to the grid size
# ---> 28         self.grid = Grid(grid_size, np_static_obstacles)
# ...
